# %%
from torchvision import transforms
import os
import torch
import torch.nn.functional as F
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
# dp_path0 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose/00006_00.jpg.npy'
dp_path0 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat/00069_00 copy 2.jpg.npy'
# dp_path1 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose/00008_00.jpg.npy'
dp_path1 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat/00069_00 copy 9.jpg.npy'

# dp_path = '/home/nfs/jsh/HierarchicalProbabilistic3DHuman/output/my2/range/iuv_0.npy'
# dp_i_path0 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose_i/00006_00.jpg.npy'
dp_i_path0 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_i_fat/00069_00 copy 2.jpg.npy'
# dp_i_path1 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose_i/00008_00.jpg.npy'
dp_i_path1 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_i_fat/00069_00 copy 9.jpg.npy'


data1_uv = np.load(dp_path1).round(decimals=2)
data1_i = np.load(dp_i_path1)

data1 = np.concatenate([data1_uv,data1_i],axis=0)

data0_uv = np.load(dp_path0).round(decimals=2)
data0_i = np.load(dp_i_path0)

data0 = np.concatenate([data0_uv,data0_i],axis=0)
print(data0_i.shape)

plt.subplot(1,2,1)
# 绘制图像
plt.imshow(data0_i[0], cmap='gray')
# 添加颜色条
plt.colorbar()

# 显示坐标为[94.0, 353.0]的点为红色圆圈
# circle = plt.Circle((420.0, 148.0), radius=5, color='red', fill=False)
# plt.gca().add_patch(circle)

# 显示坐标为[94.0, 353.0]的点为红色圆圈
circle = plt.Circle((340.0, 103.0), radius=5, color='red', fill=False)
plt.gca().add_patch(circle)

plt.subplot(1,2,2)
# 绘制图像
plt.imshow(data1_i[0], cmap='gray')
# 添加颜色条
plt.colorbar()

# 定义要显示的点的坐标
points = [[104, 405], [104, 406], [104, 407],[104, 408]]

# 循环创建并显示圆圈
for point in points:
    circle = plt.Circle((point[1], point[0]), radius=5, color='red', fill=False)
    plt.gca().add_patch(circle)

# 不显示坐标轴
plt.axis('off')
plt.show()

plt.subplot(1,2,1)
# 绘制图像
plt.imshow(data0_uv[0], cmap='gray')
# 添加颜色条
plt.colorbar()

plt.subplot(1,2,2)
# 绘制图像
plt.imshow(data1_uv[0], cmap='gray')
# 添加颜色条
plt.colorbar()
# 不显示坐标轴
plt.axis('off')
plt.show()
# Out:
# (1, 1024, 768)

# %%
from torchvision import transforms
import os
import torch
import torch.nn.functional as F
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
# dp_path0 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose/00006_00.jpg.npy'
dp_path0 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat/00069_00 copy 2.jpg.npy'
# dp_path1 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose/00008_00.jpg.npy'
dp_path1 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat/00069_00 copy 9.jpg.npy'

# dp_path = '/home/nfs/jsh/HierarchicalProbabilistic3DHuman/output/my2/range/iuv_0.npy'
# dp_i_path0 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose_i/00006_00.jpg.npy'
dp_i_path0 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_i_fat/00069_00 copy 2.jpg.npy'
# dp_i_path1 = '/HOME/HOME/jisihui/VITON-hd-resized/try/densepose_i/00008_00.jpg.npy'
dp_i_path1 = '/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_i_fat/00069_00 copy 9.jpg.npy'


data1_uv = np.load(dp_path1).round(decimals=2)
data1_i = np.load(dp_i_path1)

data1 = np.concatenate([data1_uv,data1_i],axis=0)

data0_uv = np.load(dp_path0).round(decimals=2)
data0_i = np.load(dp_i_path0)

data0 = np.concatenate([data0_uv,data0_i],axis=0)
print(data0_i.shape)

plt.subplot(1,2,1)
# 绘制图像
plt.imshow(data0_uv[0], cmap='gray')
# 添加颜色条
plt.colorbar()

# 显示坐标为[94.0, 353.0]的点为红色圆圈
# circle = plt.Circle((420.0, 148.0), radius=5, color='red', fill=False)
# plt.gca().add_patch(circle)


cc = np.load('/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat_cor/00069_00 copy 9.jpg.npy',allow_pickle=True)
p1=[]
p2=[]
for i in range(1024):
    for j in range(768):
            if cc[i,j,0]!=-1:
                # print(c[i,j])
                p1.append((j,i))
                p2.append((cc[i,j,1],cc[i,j,0]))
                # print((cc[i,j,0],cc[i,j,1]),(i,j))


# 循环创建并显示圆圈
for i in range(len(p1)):
    circle = plt.Circle(p1[i], radius=5, color='red', fill=False)
    plt.gca().add_patch(circle)

plt.subplot(1,2,2)
# 绘制图像
plt.imshow(data1_uv[0], cmap='gray')
# 添加颜色条
plt.colorbar()

# 循环创建并显示圆圈
for i in range(len(p1)):
    circle = plt.Circle(p2[i], radius=5, color='red', fill=False)
    plt.gca().add_patch(circle)

# 不显示坐标轴
plt.axis('off')
plt.show()
# Out:
# (1, 1024, 768)

# %%
import numpy as np
cc = np.load('/home/nfs/jsh/HOME/VITON-hd-resized/try2.0/densepose_fat_cor_base/00069_00 copy 2.jpg.npy',allow_pickle=True)
cc.shape
a=torch.tensor([1, 10, 2, 1024, 768])
a[:, :,:,::2,::2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/nfs/jsh/DisCo/tsv_example/cor.ipynb Cell 3 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bji-jupyter-7263813927548809216-22.k8s-inspur-nm225-cluster.dros-cluster-lbs.zhejianglab.com/home/nfs/jsh/DisCo/tsv_example/cor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> cc.shape
#       <a href='vscode-notebook-cell://ssh-remote%2Bji-jupyter-7263813927548809216-22.k8s-inspur-nm225-cluster.dros-cluster-lbs.zhejianglab.com/home/nfs/jsh/DisCo/tsv_example/cor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> a=torch.tensor([1, 10, 2, 1024, 768])
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bji-jupyter-7263813927548809216-22.k8s-inspur-nm225-cluster.dros-cluster-lbs.zhejianglab.com/home/nfs/jsh/DisCo/tsv_example/cor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> a[:, :,:,::2,::2]
#
# IndexError: too many indices for tensor of dimension 1
